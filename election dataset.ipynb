# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from datetime import datetime

# %%
df=pd.read_csv(r"C:\Users\shasa\OneDrive\Desktop\Book1.csv")
df.head()
# Out:
#               submission_id      submission_date        ph_num  AC_num  \
# 0  610b61421c1bbf76f6f59755  2021-08-05 09:10:20  9.140540e+09     224
# 1  610b639e506b3b060c006dc4  2021-08-05 08:18:39  9.627410e+09      82
# 2  610b6bc0eb775806058eb59b  2021-08-05 09:38:57  9.997932e+09      82
# 3  610b759f1c1bbf76f6f5a496  2021-08-05 09:32:10  8.840877e+09     324
# 4  610b7851eb775806058ebcb9  2021-08-05 10:42:35  9.678869e+09     324
#
#           AC   age  gender religion ls_19         vs_17  \
# 0  मऊरानीपुर  28.0    Male    Hindu   BJP  Did Not Vote
# 1       मांट  53.0    Male    Hindu   BJP           BSP
# 2       मांट  24.0    Male    Hindu   BJP           BJP
# 3    सहजनवां  30.0    Male    Hindu   MGB           BSP
# 4    सहजनवां  19.0  Female    Hindu   BJP  Did Not Vote
#
#                           caste                               monthly_income  \
# 0                   कोरी (Kori)  5,000 रु. - 10,000 रु. (₹ 5,000 - ₹ 10,000)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   submission_id     2000 non-null   object
#  1   submission_date   2000 non-null   object
#  2   ph_num            1960 non-null   float64
#  3   AC_num            2000 non-null   int64
#  4   AC                2000 non-null   object
#  5   age               1972 non-null   float64
#  6   gender            1987 non-null   object
#  7   religion          1972 non-null   object
#  8   ls_19             1952 non-null   object
#  9   vs_17             1957 non-null   object
#  10  caste             1961 non-null   object
#  11  monthly_income    1972 non-null   object
#  12  occupation        1960 non-null   object
#  13  satisfation_cm    1958 non-null   object
#  14  satisfation_PM    1958 non-null   object
#  15  mla_satisfaction  1562 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['submission_id', 'submission_date', 'ph_num', 'AC_num', 'AC', 'age',
#        'gender', 'religion', 'ls_19', 'vs_17', 'caste', 'monthly_income',
#        'occupation', 'satisfation_cm', 'satisfation_PM', 'mla_satisfaction',
#        'mla_choice', 'cm_choice'],
#       dtype='object')

# %%
df.describe()
# Out:
#              ph_num       AC_num          age
# count  1.960000e+03  2000.000000  1972.000000
# mean   8.635482e+09   197.609500    39.130325
# std    1.077027e+09   110.569412    13.932276
# min    6.261694e+09     8.000000    18.000000
# 25%    7.817743e+09   110.000000    28.000000
# 50%    8.893513e+09   188.000000    36.000000
# 75%    9.628182e+09   296.000000    50.000000
# max    9.999492e+09   402.000000    85.000000

# %% [markdown]
# In Data Analysis What All Things We Do
#
# Missing Values
#
# Explore About the Numerical Variables
#
# Explore About categorical Variables
#
# Finding Relationship between features

# %%
df.shape
# Out:
# (2000, 18)

# %%
df.isnull().sum()
# Out:
# submission_id         0
# submission_date       0
# ph_num               40
# AC_num                0
# AC                    0
# age                  28
# gender               13
# religion             28
# ls_19                48
# vs_17                43
# caste                39
# monthly_income       28
# occupation           40
# satisfation_cm       42
# satisfation_PM       42
# mla_satisfaction    438
# mla_choice           45
# cm_choice            46
# dtype: int64

# %%
df.fillna(value = 0, inplace = True)

# %%
df.isnull().sum()
# Out:
# submission_id       0
# submission_date     0
# ph_num              0
# AC_num              0
# AC                  0
# age                 0
# gender              0
# religion            0
# ls_19               0
# vs_17               0
# caste               0
# monthly_income      0
# occupation          0
# satisfation_cm      0
# satisfation_PM      0
# mla_satisfaction    0
# mla_choice          0
# cm_choice           0
# dtype: int64

# %%
df.head()
# Out:
#               submission_id      submission_date        ph_num  AC_num  \
# 0  610b61421c1bbf76f6f59755  2021-08-05 09:10:20  9.140540e+09     224
# 1  610b639e506b3b060c006dc4  2021-08-05 08:18:39  9.627410e+09      82
# 2  610b6bc0eb775806058eb59b  2021-08-05 09:38:57  9.997932e+09      82
# 3  610b759f1c1bbf76f6f5a496  2021-08-05 09:32:10  8.840877e+09     324
# 4  610b7851eb775806058ebcb9  2021-08-05 10:42:35  9.678869e+09     324
#
#           AC   age  gender religion ls_19         vs_17  \
# 0  मऊरानीपुर  28.0    Male    Hindu   BJP  Did Not Vote
# 1       मांट  53.0    Male    Hindu   BJP           BSP
# 2       मांट  24.0    Male    Hindu   BJP           BJP
# 3    सहजनवां  30.0    Male    Hindu   MGB           BSP
# 4    सहजनवां  19.0  Female    Hindu   BJP  Did Not Vote
#
#                           caste                               monthly_income  \
# 0                   कोरी (Kori)  5,000 रु. - 10,000 रु. (₹ 5,000 - ₹ 10,000)
# ...

# %%
df['ls_19'].value_counts()
# Out:
# BJP                1139
# MGB                 582
# Did Not Vote        143
# 0                    48
# Do Not Remember      43
# INC                  27
# Others               16
# NOTA                  2
# Name: ls_19, dtype: int64

# %%
votes=df.groupby(['AC'])['ls_19'].value_counts()
votes
# Out:
# AC        ls_19
# Bahraich  BJP                11
#           MGB                10
#           Did Not Vote        3
#           0                   1
#           Do Not Remember     1
#                              ..
# हरैया     MGB                 3
#           Do Not Remember     1
# हुसैनगंज  BJP                 4
#           MGB                 3
#           Do Not Remember     1
# Name: ls_19, Length: 391, dtype: int64

# %%
voter=df.groupby(['AC'])['vs_17'].value_counts()
voter
# Out:
# AC        vs_17
# Bahraich  BJP                9
#           Did Not Vote       7
#           SP                 5
#           BSP                2
#           Do Not Remember    2
#                             ..
# हरैया     SP                 1
# हुसैनगंज  BJP                4
#           BSP                2
#           Do Not Remember    1
#           INC                1
# Name: vs_17, Length: 516, dtype: int64

# %%
newdf = df[(df.occupation == "बेरोजगार") & (df.gender == "Female")& (df.vs_17=="Did Not Vote")]
newdf.head()
# Out:
#                  submission_id      submission_date        ph_num  AC_num  \
# 642   611a86cd0f7a4124613b5e15  2021-08-16 12:31:33  9.627221e+09      71
# 1347  6124afae616d3e3923784c6e  2021-08-24 10:15:58  9.005606e+09     402
# 1391  6124edbe98f2df3948dbd92b  2021-08-24 17:34:42  9.935013e+09     188
# 1775  6128d708910d9633c933a6c4  2021-08-27 17:17:12  8.650467e+09     110
#
#               AC   age  gender religion         ls_19         vs_17  \
# 642          खैर  19.0  Female    Hindu  Did Not Vote  Did Not Vote
# 1347        ओबरा  28.0  Female   Muslim           MGB  Did Not Vote
# 1391  सुल्तानपुर  24.0  Female    Hindu           BJP  Did Not Vote
# 1775       कराहल  20.0  Female    Hindu  Did Not Vote  Did Not Vote
#
#                                caste  \
# 642   खटिक / सोनकर (Khatik / Sonkar)
# 1347                          Muslim
# 1391     कश्यप/ कहार (Kashyap/Kahar)
# 1775              कठेरिया (Katheria)
#
# ...

# %%
df.corr()
# Out:
#           ph_num    AC_num       age
# ph_num  1.000000 -0.032042  0.241159
# AC_num -0.032042  1.000000  0.036994
# age     0.241159  0.036994  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
votes_counts=df['ls_19'].value_counts().reset_index()
votes_counts
# Out:
#              index  ls_19
# 0              BJP   1139
# 1              MGB    582
# 2     Did Not Vote    143
# 3                0     48
# 4  Do Not Remember     43
# 5              INC     27
# 6           Others     16
# 7             NOTA      2

# %%
fig = plt.figure(figsize =(10, 7))

df.ls_19.value_counts(normalize=True).plot(kind='pie')
plt.show()

# %% [markdown]
# Finding the null values of the dataset and their percentage in each column.

# %%
df=pd.read_csv(r"C:\Users\shasa\OneDrive\Desktop\Book1.csv")

# %%
df.isnull().sum()
# Out:
# submission_id         0
# submission_date       0
# ph_num               40
# AC_num                0
# AC                    0
# age                  28
# gender               13
# religion             28
# ls_19                48
# vs_17                43
# caste                39
# monthly_income       28
# occupation           40
# satisfation_cm       42
# satisfation_PM       42
# mla_satisfaction    438
# mla_choice           45
# cm_choice            46
# dtype: int64

# %%
df.isnull().sum()*100/len(df) #to make into decimals
# Out:
# submission_id        0.00
# submission_date      0.00
# ph_num               2.00
# AC_num               0.00
# AC                   0.00
# age                  1.40
# gender               0.65
# religion             1.40
# ls_19                2.40
# vs_17                2.15
# caste                1.95
# monthly_income       1.40
# occupation           2.00
# satisfation_cm       2.10
# satisfation_PM       2.10
# mla_satisfaction    21.90
# mla_choice           2.25
# cm_choice            2.30
# dtype: float64
